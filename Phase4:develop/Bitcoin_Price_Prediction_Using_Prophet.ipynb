# %% [markdown]
# # **Import Necessary Libraries**
#
# ---

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go

from datetime import datetime as dt
from datetime import timedelta as td

# %% [markdown]
# # **Loading the Dataset**
#
# ---

# %%
import yfinance as yf

# %%
st_date = "2016-01-01"
td_date = dt.today().strftime("%Y-%m-%d")

print("Starting Date:", st_date)
print("Today's Date :", td_date)
# Out:
# Starting Date: 2016-01-01
# Today's Date : 2023-11-02

# %%
df = yf.download("BTC-USD", st_date, td_date)
df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-01  430.721008  436.246002  427.515015  434.334015  434.334015
# 2016-01-02  434.622009  436.062012  431.869995  433.437988  433.437988
# 2016-01-03  433.578003  433.743011  424.705994  430.010986  430.010986
# 2016-01-04  430.061005  434.516998  429.084015  433.091003  433.091003
# 2016-01-05  433.069000  434.182007  429.675995  431.959991  431.959991
#
#               Volume
# Date
# 2016-01-01  36278900
# 2016-01-02  30096600
# 2016-01-03  39633800
# 2016-01-04  38477500
# 2016-01-05  34522600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2862 entries, 2016-01-01 to 2023-11-01
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2862 non-null   float64
#  1   High       2862 non-null   float64
#  2   Low        2862 non-null   float64
#  3   Close      2862 non-null   float64
#  4   Adj Close  2862 non-null   float64
#  5   Volume     2862 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 156.5 KB

# %%
df.shape
# Out:
# (2862, 6)

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   2862.000000   2862.000000   2862.000000   2862.000000   2862.000000
# mean   16397.794126  16786.357058  15976.882811  16408.447428  16408.447428
# std    16137.430435  16534.000945  15686.914678  16135.236348  16135.236348
# min      365.072998    374.950012    354.914001    364.330994    364.330994
# 25%     4034.599426   4110.110962   3968.972778   4039.051270   4039.051270
# 50%     9484.943848   9671.880859   9282.042480   9487.736816   9487.736816
# 75%    26533.612305  26909.723145  26173.731934  26560.643066  26560.643066
# max    67549.734375  68789.625000  66382.062500  67566.828125  67566.828125
#
#              Volume
# count  2.862000e+03
# mean   1.917040e+10
# std    1.945663e+10
# min    2.851400e+07
# 25%    3.671598e+09
# 50%    1.564545e+10
# 75%    2.992057e+10
# max    3.509679e+11

# %% [markdown]
# # **Checking for NULL Values**
#
# ---

# %%
df.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# # **Resetting Dataframe Index**
#
# ---

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2016-01-01  430.721008  436.246002  427.515015  434.334015  434.334015
# 1 2016-01-02  434.622009  436.062012  431.869995  433.437988  433.437988
# 2 2016-01-03  433.578003  433.743011  424.705994  430.010986  430.010986
# 3 2016-01-04  430.061005  434.516998  429.084015  433.091003  433.091003
# 4 2016-01-05  433.069000  434.182007  429.675995  431.959991  431.959991
#
#      Volume
# 0  36278900
# 1  30096600
# 2  39633800
# 3  38477500
# 4  34522600

# %% [markdown]
# # **Data Visualisation**
#
# ---

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df["Date"], y=df["Open"]))

fig.update_layout(
    title_text = "Time Series of Bitcoin Opening Price",
    xaxis = dict(

                rangeselector = dict(

                    buttons=list(
                        [
                            dict(count=1, label = "1 month",
                                 step="month", stepmode="backward"),
                            dict(count=6, label = "6 months",
                                 step="month", stepmode = "backward"),
                            dict(count=1, label = "1 Year",
                                step="year", stepmode="backward"),
                            dict(count=1, label = "To This Year",
                                step="year", stepmode="todate")
                        ]
                      )
                ),
                rangeslider = dict(visible = True),
                title = "Date",
    )
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="26fe9028-20cc-49f7-a952-75a746622b0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26fe9028-20cc-49f7-a952-75a746622b0f")) {                    Plotly.newPlot(                        "26fe9028-20cc-49f7-a952-75a746622b0f",                        [{"x":["2016-01-01T00:00:00","2016-01-02T00:00:00","2016-01-03T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-09T00:00:00","2016-01-10T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-16T00:00:00","2016-01-17T00:00:00","2016-01-18T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-23T00:00:00","2016-01-24T00:00:00","2016-01-25T00:00:00","2016-01-26T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-01-30T00:00:00","2016-01-31T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00","2016-02-05T00:00:00","2016-02-06T00:00:00","2016-02-07T00:00:00","2016-02-08T00:00:00","2016-02-09T00:00:00","2016-02-10T00:00:00","2016-02-11T00:00:00","2016-02-12T00:00:00","2016-02-13T00:00:00","2016-02-14T00:00:00","2016-02-15T00:00:00","2016-02-16T00:00:00","2016-02-17T00:00:00","2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-20T00:00:00","2016-02-21T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-27T00:00:00","2016-02-28T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-05T00:00:00","2016-03-06T00:00:00","2016-03-07T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-12T00:00:00","2016-03-13T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-19T00:00:00","2016-03-20T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-24T00:00:00","2016-03-25T00:00:00","2016-03-26T00:00:00","2016-03-27T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-02T00:00:00","2016-04-03T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-09T00:00:00","2016-04-10T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-14T00:00:00","2016-04-15T00:00:00","2016-04-16T00:00:00","2016-04-17T00:00:00","2016-04-18T00:00:00","2016-04-19T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-23T00:00:00","2016-04-24T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-04-30T00:00:00","2016-05-01T00:00:00","2016-05-02T00:00:00","2016-05-03T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-07T00:00:00","2016-05-08T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-14T00:00:00","2016-05-15T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-21T00:00:00","2016-05-22T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-28T00:00:00","2016-05-29T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:00:00","2016-06-02T00:00:00","2016-06-03T00:00:00","2016-06-04T00:00:00 ...

# %% [markdown]
# #**Preparing Training Data**
#
# ---

# %%
X_train = df.iloc[:,:2]

# %%
X_train.head()
# Out:
#         Date        Open
# 0 2016-01-01  430.721008
# 1 2016-01-02  434.622009
# 2 2016-01-03  433.578003
# 3 2016-01-04  430.061005
# 4 2016-01-05  433.069000

# %% [markdown]
# ## **Renaming Columns for Model Training Purpose**
#
# ---

# %%
X_train.columns = ["ds", "y"]

# %%
X_train.head()
# Out:
#           ds           y
# 0 2016-01-01  430.721008
# 1 2016-01-02  434.622009
# 2 2016-01-03  433.578003
# 3 2016-01-04  430.061005
# 4 2016-01-05  433.069000

# %% [markdown]
# # **Model Building**
#
# ---

# %% [markdown]
# ## **Downloading Prophet Library**
#
# ---

# %%
# !python -m pip install prophet
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (1.1.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.2.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.23.5)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (3.7.1)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.5.3)
# Requirement already satisfied: holidays>=0.25 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.35)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet) (4.66.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet) (6.1.0)
# Requirement already satisfied: stanio~=0.3.0 in /usr/local/lib/python3.10/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.3.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (3.1.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)

# %% [markdown]
# ## **Importing Prophet Library**
#
# ---

# %%
from prophet import Prophet

# %% [markdown]
# ## **Model Initialisation**
#
# ---

# %%
prophet_model = Prophet(seasonality_mode = "multiplicative")

# %% [markdown]
# ## **Training the Model**
#
# ---

# %%
prophet_model.fit(X_train)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpck6aktvm/uqb9otjc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpck6aktvm/i5xj_r_u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94845', 'data', 'file=/tmp/tmpck6aktvm/uqb9otjc.json', 'init=/tmp/tmpck6aktvm/i5xj_r_u.json', 'output', 'file=/tmp/tmpck6aktvm/prophet_modelqq74kn2n/prophet_model-20231102121920.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:19:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:19:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# ## **Making Predictions**
#
# ---

# %%
f_df = prophet_model.make_future_dataframe(periods=365)

# %%
f_df.head()
# Out:
#           ds
# 0 2016-01-01
# 1 2016-01-02
# 2 2016-01-03
# 3 2016-01-04
# 4 2016-01-05

# %%
f_df.tail()
# Out:
#              ds
# 3222 2024-10-27
# 3223 2024-10-28
# 3224 2024-10-29
# 3225 2024-10-30
# 3226 2024-10-31

# %%
y_preds = prophet_model.predict(f_df)

# %%
y_preds.head()
# Out:
#           ds      trend   yhat_lower   yhat_upper  trend_lower  trend_upper  \
# 0 2016-01-01 -30.261538 -4955.264665  4959.678618   -30.261538   -30.261538
# 1 2016-01-02 -27.375481 -5374.614821  5035.534886   -27.375481   -27.375481
# 2 2016-01-03 -24.489424 -4632.962581  4946.901613   -24.489424   -24.489424
# 3 2016-01-04 -21.603367 -5082.894529  5146.929005   -21.603367   -21.603367
# 4 2016-01-05 -18.717310 -4657.414252  4603.899456   -18.717310   -18.717310
#
#    multiplicative_terms  multiplicative_terms_lower  \
# 0             -0.009048                   -0.009048
# 1             -0.002222                   -0.002222
# 2              0.003619                    0.003619
# 3              0.009075                    0.009075
# 4              0.012346                    0.012346
#
#    multiplicative_terms_upper    weekly  weekly_lower  weekly_upper    yearly  \
# 0                   -0.009048 -0.002019     -0.002019     -0.002019 -0.007029
# 1                   -0.002222 -0.001131     -0.001131     -0.001131 -0.001091
# 2                    0.003619 -0.000433     -0.000433     -0.000433  0.004052
# 3                    0.009075  0.000782      0.000782      0.000782  0.008294
# 4                    0.012346  0.000798      0.000798      0.000798  0.011549
#
#    yearly_lower  yearly_upper  additive_terms  additive_terms_lower  \
# 0     -0.007029     -0.007029             0.0                   0.0
# 1     -0.001091     -0.001091             0.0                   0.0
# 2      0.004052      0.004052             0.0                   0.0
# 3      0.008294      0.008294             0.0                   0.0
# 4      0.011549      0.011549             0.0                   0.0
#
#    additive_terms_upper       yhat
# 0                   0.0 -29.987724
# 1                   0.0 -27.314642
# 2                   0.0 -24.578043
# 3                   0.0 -21.799426
# 4                   0.0 -18.948399

# %%
y_preds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3227 entries, 0 to 3226
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ds                          3227 non-null   datetime64[ns]
#  1   trend                       3227 non-null   float64
#  2   yhat_lower                  3227 non-null   float64
#  3   yhat_upper                  3227 non-null   float64
#  4   trend_lower                 3227 non-null   float64
#  5   trend_upper                 3227 non-null   float64
#  6   multiplicative_terms        3227 non-null   float64
#  7   multiplicative_terms_lower  3227 non-null   float64
#  8   multiplicative_terms_upper  3227 non-null   float64
#  9   weekly                      3227 non-null   float64
#  10  weekly_lower                3227 non-null   float64
#  11  weekly_upper                3227 non-null   float64
#  12  yearly                      3227 non-null   float64
#  13  yearly_lower                3227 non-null   float64
#  14  yearly_upper                3227 non-null   float64
#  15  additive_terms              3227 non-null   float64
#  16  additive_terms_lower        3227 non-null   float64
#  17  additive_terms_upper        3227 non-null   float64
#  18  yhat                        3227 non-null   float64
# dtypes: datetime64[ns](1), float64(18)
# memory usage: 479.1 KB

# %%
view_cols = ["ds", "yhat", "yhat_lower", "yhat_upper"]
y_preds[view_cols]
# Out:
#              ds          yhat   yhat_lower    yhat_upper
# 0    2016-01-01    -29.987724 -4955.264665   4959.678618
# 1    2016-01-02    -27.314642 -5374.614821   5035.534886
# 2    2016-01-03    -24.578043 -4632.962581   4946.901613
# 3    2016-01-04    -21.799426 -5082.894529   5146.929005
# 4    2016-01-05    -18.948399 -4657.414252   4603.899456
# ...         ...           ...          ...           ...
# 3222 2024-10-27  24646.227025  6134.214170  44577.856091
# 3223 2024-10-28  24707.947205  6016.201487  45488.907526
# 3224 2024-10-29  24721.299218  5610.716021  46045.940309
# 3225 2024-10-30  24704.118041  6281.461013  45302.716825
# 3226 2024-10-31  24710.754419  5822.643085  46074.529687
#
# [3227 rows x 4 columns]

# %% [markdown]
# ## **Future Predictions**
#
# ---

# %%
next_day = (dt.today() + td(days=1)).strftime("%Y-%m-%d")
next_day
# Out:
# '2023-11-03'

# %%
y_preds[y_preds["ds"] == next_day][view_cols]
# Out:
#              ds          yhat    yhat_lower   yhat_upper
# 2863 2023-11-03  26398.829022  21572.512701  31299.63957

# %% [markdown]
# ## **Plotting Future Predictions**
#
# ---

# %%
from prophet.plot import plot_plotly, plot_components_plotly

# %%
plot_plotly(prophet_model, y_preds)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="33b94133-1788-403a-b42a-ff27d11e74a5" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33b94133-1788-403a-b42a-ff27d11e74a5")) {                    Plotly.newPlot(                        "33b94133-1788-403a-b42a-ff27d11e74a5",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","x":["2016-01-01T00:00:00","2016-01-02T00:00:00","2016-01-03T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-09T00:00:00","2016-01-10T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-16T00:00:00","2016-01-17T00:00:00","2016-01-18T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-23T00:00:00","2016-01-24T00:00:00","2016-01-25T00:00:00","2016-01-26T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-01-30T00:00:00","2016-01-31T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00","2016-02-05T00:00:00","2016-02-06T00:00:00","2016-02-07T00:00:00","2016-02-08T00:00:00","2016-02-09T00:00:00","2016-02-10T00:00:00","2016-02-11T00:00:00","2016-02-12T00:00:00","2016-02-13T00:00:00","2016-02-14T00:00:00","2016-02-15T00:00:00","2016-02-16T00:00:00","2016-02-17T00:00:00","2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-20T00:00:00","2016-02-21T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-27T00:00:00","2016-02-28T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-05T00:00:00","2016-03-06T00:00:00","2016-03-07T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-12T00:00:00","2016-03-13T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-19T00:00:00","2016-03-20T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-24T00:00:00","2016-03-25T00:00:00","2016-03-26T00:00:00","2016-03-27T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-02T00:00:00","2016-04-03T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-09T00:00:00","2016-04-10T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-14T00:00:00","2016-04-15T00:00:00","2016-04-16T00:00:00","2016-04-17T00:00:00","2016-04-18T00:00:00","2016-04-19T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-23T00:00:00","2016-04-24T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-04-30T00:00:00","2016-05-01T00:00:00","2016-05-02T00:00:00","2016-05-03T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-07T00:00:00","2016-05-08T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-14T00:00:00","2016-05-15T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-21T00:00:00","2016-05-22T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-28T00:00:00","2016-05-29T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:0 ...

# %%
plot_components_plotly(prophet_model, y_preds)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4f7f222e-4f80-4aca-bb40-8947e999ecde" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f7f222e-4f80-4aca-bb40-8947e999ecde")) {                    Plotly.newPlot(                        "4f7f222e-4f80-4aca-bb40-8947e999ecde",                        [{"line":{"color":"#0072B2","width":2},"mode":"lines","name":"trend","x":["2016-01-01T00:00:00","2016-01-02T00:00:00","2016-01-03T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-09T00:00:00","2016-01-10T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-16T00:00:00","2016-01-17T00:00:00","2016-01-18T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-23T00:00:00","2016-01-24T00:00:00","2016-01-25T00:00:00","2016-01-26T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-01-30T00:00:00","2016-01-31T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00","2016-02-05T00:00:00","2016-02-06T00:00:00","2016-02-07T00:00:00","2016-02-08T00:00:00","2016-02-09T00:00:00","2016-02-10T00:00:00","2016-02-11T00:00:00","2016-02-12T00:00:00","2016-02-13T00:00:00","2016-02-14T00:00:00","2016-02-15T00:00:00","2016-02-16T00:00:00","2016-02-17T00:00:00","2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-20T00:00:00","2016-02-21T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-27T00:00:00","2016-02-28T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-05T00:00:00","2016-03-06T00:00:00","2016-03-07T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-12T00:00:00","2016-03-13T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-19T00:00:00","2016-03-20T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-24T00:00:00","2016-03-25T00:00:00","2016-03-26T00:00:00","2016-03-27T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-02T00:00:00","2016-04-03T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-09T00:00:00","2016-04-10T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-14T00:00:00","2016-04-15T00:00:00","2016-04-16T00:00:00","2016-04-17T00:00:00","2016-04-18T00:00:00","2016-04-19T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-23T00:00:00","2016-04-24T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-04-30T00:00:00","2016-05-01T00:00:00","2016-05-02T00:00:00","2016-05-03T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-07T00:00:00","2016-05-08T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-14T00:00:00","2016-05-15T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-21T00:00:00","2016-05-22T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-28T00:00:00","2016-05-29T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:00: ...

# %% [markdown]
# # **Saving the Model**
#
# ---

# %%
import pickle
pickle.dump(prophet_model,open('fbcrypto.pkl','wb'))
